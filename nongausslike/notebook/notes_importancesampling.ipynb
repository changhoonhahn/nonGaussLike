# %% [markdown]
# Use importance sampling to estimate the posterior distribution of ICA parameter constraints

# %%
import numpy as np
import corner as DFM

import env
import util as UT
import nongauss as NG

# %%
import matplotlib as mpl 
import matplotlib.pyplot as plt 
mpl.rcParams['text.usetex'] = True
mpl.rcParams['font.family'] = 'serif'
mpl.rcParams['axes.linewidth'] = 1.5
mpl.rcParams['axes.xmargin'] = 1
mpl.rcParams['xtick.labelsize'] = 'x-large'
mpl.rcParams['xtick.major.size'] = 5
mpl.rcParams['xtick.major.width'] = 1.5
mpl.rcParams['ytick.labelsize'] = 'x-large'
mpl.rcParams['ytick.major.size'] = 5
mpl.rcParams['ytick.major.width'] = 1.5
mpl.rcParams['legend.frameon'] = False
# %matplotlib inline

# %% [markdown]
# First read in Florian's MCMC chain

# %%
zbin = 1
n_chain = 1

f = ''.join([UT.dat_dir(), 'Beutler/public_full_shape/',         
             'Beutler_et_al_full_shape_analysis_z', str(zbin), '_chain', str(n_chain), '.dat'])
mcmc_chain = np.loadtxt(f, skiprows=1, usecols=range(1,12))

# %%
labels = [r'$\alpha_\perp$', r'$\alpha_\parallel$', '$f\sigma_8$',
          '$b_1^\mathrm{NGC} \sigma_8$', '$b_1^\mathrm{SGC}\sigma_8$',
          '$b_2^\mathrm{NGC} \sigma_8$', '$b_2^\mathrm{SGC}\sigma_8$',
          '$N_\mathrm{NGC}$', '$N_\mathrm{SGC}$', '$\sigma_v^\mathrm{NGC}$', '$\sigma_v^\mathrm{SGC}$']
fig = DFM.corner(mcmc_chain, labels=labels)

# %%
mcmc_chain_thin = mcmc_chain[::16]
# Out:
# (4500, 11)
