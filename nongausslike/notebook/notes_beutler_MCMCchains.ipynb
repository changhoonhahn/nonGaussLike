# %% [markdown]
# Just curious how Florian's chains work

# %%
import numpy as np 
import corner as DFM

import env
import util as UT

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# read in the chains

# %%
zbin = 1 
ichain = 1
f = ''.join([UT.dat_dir(), 'Beutler/public_full_shape/',         
             'Beutler_et_al_full_shape_analysis_z', str(zbin), '_chain', str(ichain), '.dat'])
chain = np.loadtxt(f, skiprows=1, usecols=range(1,12))

# %%
print chain.shape
# Out:
# (72000, 11)

# %%
DFM.corner(chain, 
           labels=['alpha_perp', 'alpha_para', 'fsig8', 'b1sig8_NGC', 'b1sig8_SGC', 'b2sig8_NGC', 'b2sig8_SGC','N_NGC', 'N_SGC', 'sigmav_NGC', 'sigmav_SGC', 'chi2'])
